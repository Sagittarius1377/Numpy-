# %%
import pandas as pd 
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.to_csv('titanic.csv',index=False)

# %%
#  for reading 
df = pd.read_csv("titanic.csv")

# %%
# to show first 5 record
#  By default , first record is seen as column name in pandas 
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
# to watch last 5 records

df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# for data-columns-names
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# to see data of one particular column 
df['survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
type(df['survived'])
# Out:
# pandas.core.series.Series

# %%
df[['survived']]
# Out:
#      survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
type(df[['survived']])
# Out:
# pandas.core.frame.DataFrame

# %%
# for multiple columns 

df[['survived', 'class']]
# Out:
#      survived   class
# 0           0   Third
# 1           1   First
# 2           1   Third
# 3           1   First
# 4           0   Third
# ..        ...     ...
# 886         0  Second
# 887         1   First
# 888         0   Third
# 889         1   First
# 890         0   Third
#
# [891 rows x 2 columns]

# %%
# for datatypes of columns
df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df[['sex', 'embarked','class','who','deck','embark_town','alive']]
# Out:
#         sex embarked   class    who deck  embark_town alive
# 0      male        S   Third    man  NaN  Southampton    no
# 1    female        C   First  woman    C    Cherbourg   yes
# 2    female        S   Third  woman  NaN  Southampton   yes
# 3    female        S   First  woman    C  Southampton   yes
# 4      male        S   Third    man  NaN  Southampton    no
# ..      ...      ...     ...    ...  ...          ...   ...
# 886    male        S  Second    man  NaN  Southampton    no
# 887  female        S   First  woman    B  Southampton   yes
# 888  female        S   Third  woman  NaN  Southampton    no
# 889    male        C   First    man    C    Cherbourg   yes
# 890    male        Q   Third    man  NaN   Queenstown    no
#
# [891 rows x 7 columns]

# %%
df.dtypes == 'object'
# Out:
# survived       False
# pclass         False
# sex             True
# age            False
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class           True
# who             True
# adult_male     False
# deck            True
# embark_town     True
# alive           True
# alone          False
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# sex            object
# embarked       object
# class          object
# who            object
# deck           object
# embark_town    object
# alive          object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive'], dtype='object')

# %%
type(df.dtypes[df.dtypes == 'object'])
# Out:
# pandas.core.series.Series

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#         sex embarked   class    who deck  embark_town alive
# 0      male        S   Third    man  NaN  Southampton    no
# 1    female        C   First  woman    C    Cherbourg   yes
# 2    female        S   Third  woman  NaN  Southampton   yes
# 3    female        S   First  woman    C  Southampton   yes
# 4      male        S   Third    man  NaN  Southampton    no
# ..      ...      ...     ...    ...  ...          ...   ...
# 886    male        S  Second    man  NaN  Southampton    no
# 887  female        S   First  woman    B  Southampton   yes
# 888  female        S   Third  woman  NaN  Southampton    no
# 889    male        C   First    man    C    Cherbourg   yes
# 890    male        Q   Third    man  NaN   Queenstown    no
#
# [891 rows x 7 columns]

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#          sex embarked  class  who deck  embark_town alive
# count    891      889    891  891  203          889   891
# unique     2        3      3    3    7            3     2
# top     male        S  Third  man    C  Southampton    no
# freq     577      644    491  537   59          644   549

# %%
df[df.dtypes[df.dtypes == 'float'].index]
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df[df.dtypes[df.dtypes == 'int'].index]
# Out:
#      survived  pclass  sibsp  parch
# 0           0       3      1      0
# 1           1       1      1      0
# 2           1       3      0      0
# 3           1       1      1      0
# 4           0       3      0      0
# ..        ...     ...    ...    ...
# 886         0       2      0      0
# 887         1       1      0      0
# 888         0       3      1      2
# 889         1       1      0      0
# 890         0       3      0      0
#
# [891 rows x 4 columns]

# %%
df[['deck']][4:11]
# Out:
#    deck
# 4   NaN
# 5   NaN
# 6     E
# 7   NaN
# 8   NaN
# 9   NaN
# 10    G

# %%
df[['deck','alive']][4:11:2]
# Out:
#    deck alive
# 4   NaN    no
# 6     E    no
# 8   NaN   yes
# 10    G   yes

# %%
df['new_col'] =0

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df["new_col_1"] = df['survived'] + df['pclass']

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
# to find the categories of particular column
pd.Categorical(df['pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df['survived'])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
# to find unique
df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
# those person who is greater than 18
df[df['age']>18]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
len(df[df['age']>18])
# Out:
# 575

# %%
# person whose fare is above avg
df[df['fare']>32.204208]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 23          1       1    male  28.0      0      0   35.5000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 867         0       1    male  31.0      0      0   50.4958        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
# ...

# %%
# person who doesn't pay
df[df['fare']== 0]
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 179         0       3  male  36.0      0      0   0.0        S   Third  man
# 263         0       1  male  40.0      0      0   0.0        S   First  man
# 271         1       3  male  25.0      0      0   0.0        S   Third  man
# 277         0       2  male   NaN      0      0   0.0        S  Second  man
# 302         0       3  male  19.0      0      0   0.0        S   Third  man
# 413         0       2  male   NaN      0      0   0.0        S  Second  man
# 466         0       2  male   NaN      0      0   0.0        S  Second  man
# 481         0       2  male   NaN      0      0   0.0        S  Second  man
# 597         0       3  male  49.0      0      0   0.0        S   Third  man
# 633         0       1  male   NaN      0      0   0.0        S   First  man
# 674         0       2  male   NaN      0      0   0.0        S  Second  man
# ...

# %%
df[df['sex']== 'male']
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  new_col  new_col_1
# ...

# %%
df[df['sex']== 'female']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
# ...

# %%
df[df['pclass'] == 1 ]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# 23          1       1    male  28.0      0      0  35.5000        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
# ...

# %%
df[df['survived'] == 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
# ...

# %%
df['sex']== 'female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: sex, Length: 891, dtype: bool

# %%
df['fare']> 32.204208
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: fare, Length: 891, dtype: bool

# %%
df[(df['sex']== 'female') & (df['fare']> 32.204208)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 31          1       1  female   NaN      1      0  146.5208        C   First
# 43          1       2  female   3.0      1      2   41.5792        C  Second
# 52          1       1  female  49.0      1      0   76.7292        C   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 853         1       1  female  16.0      0      1   39.4000        S   First
# 856         1       1  female  45.0      1      1  164.8667        S   First
# 863         0       3  female   NaN      8      2   69.5500        S   Third
# 871         1       1  female  47.0      1      1   52.5542        S   First
# 879         1       1  female  56.0      0      1   83.1583        C   First
#
# ...

# %%
df[(df['sex']== 'male') & (df['fare']> 32.204208)]
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 6           0       1  male  54.0      0      0   51.8625        S   First
# 23          1       1  male  28.0      0      0   35.5000        S   First
# 27          0       1  male  19.0      3      2  263.0000        S   First
# 34          0       1  male  28.0      1      0   82.1708        C   First
# 35          0       1  male  42.0      1      0   52.0000        S   First
# ..        ...     ...   ...   ...    ...    ...       ...      ...     ...
# 827         1       2  male   1.0      0      2   37.0042        C  Second
# 838         1       3  male  32.0      0      0   56.4958        S   Third
# 846         0       3  male   NaN      8      2   69.5500        S   Third
# 848         0       2  male  28.0      0      1   33.0000        S  Second
# 867         0       1  male  31.0      0      0   50.4958        S   First
#
# ...

# %%
max(df["fare"])
# Out:
# 512.3292

# %%
df[df['fare'] == max(df['fare'])]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male deck embark_town alive  alone  new_col  new_col_1
# 258  woman       False  NaN   Cherbourg   yes   True        0          2
# 679    man        True    B   Cherbourg   yes  False        0          2
# 737    man        True    B   Cherbourg   yes   True        0          2

# %%
df[0:4]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone  new_col  new_col_1
# 0    man        True  NaN  Southampton    no  False        0          3
# 1  woman       False    C    Cherbourg   yes  False        0          2
# 2  woman       False  NaN  Southampton   yes   True        0          4
# 3  woman       False    C  Southampton   yes  False        0          2

# %%
df[['survived','pclass','sex']][0:2]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female

# %%
df.iloc[0:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone  new_col  new_col_1
# 0    man        True  NaN  Southampton    no  False        0          3
# 1  woman       False    C    Cherbourg   yes  False        0          2

# %%
df.iloc[0:2 , [0,1,2]]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female

# %%
df.loc[0:2, ['survived','pclass','sex']]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female

# %%
s =df[['who']]

# %%
s
# Out:
#        who
# 0      man
# 1    woman
# 2    woman
# 3    woman
# 4      man
# ..     ...
# 886    man
# 887  woman
# 888  woman
# 889    man
# 890    man
#
# [891 rows x 1 columns]

# %%
type(s)
# Out:
# pandas.core.frame.DataFrame

# %%
len(s)
# Out:
# 891

# %%
t =df['who'][0:10]
t
# Out:
# 0      man
# 1    woman
# 2    woman
# 3    woman
# 4      man
# 5      man
# 6      man
# 7    child
# 8    woman
# 9    child
# Name: who, dtype: object

# %%
type(t)
# Out:
# pandas.core.series.Series

# %%
# to remove index 
l=['a','b','c','d','e','f','g','h','i','j']

# %%
pd.Series(t, index=l)
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# f    NaN
# g    NaN
# h    NaN
# i    NaN
# j    NaN
# Name: who, dtype: object

# %%
t_1 = pd.Series(list(t), index=l)

# %%
t_1
# Out:
# a      man
# b    woman
# c    woman
# d    woman
# e      man
# f      man
# g      man
# h    child
# i    woman
# j    child
# dtype: object

# %%
t[0]
# Out:
# 'man'

# %%
t_1[0]
# Out:
# /tmp/ipykernel_1712/1272559337.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_1[0]
# 'man'

# %%
t_1["a"]
# Out:
# 'man'

# %%
type(t_1)
# Out:
# pandas.core.series.Series

# %%
# instead of append use pd.concat in series 
t_2 = pd.concat([t_1,t])

# %%
t_2
# Out:
# a      man
# b    woman
# c    woman
# d    woman
# e      man
# f      man
# g      man
# h    child
# i    woman
# j    child
# 0      man
# 1    woman
# 2    woman
# 3    woman
# 4      man
# 5      man
# 6      man
# 7    child
# 8    woman
# 9    child
# dtype: object

# %%
t_2[4]
# Out:
# 'man'

# %%
t_3 = pd.Series([3,9,5,6], index =[2,4,7,1])

# %%
t_4 = pd.Series([56,23,89,12,59,40] , index = [9,2,4,6,1,2])

# %%
t_5 = pd.concat([t_3, t_4])

# %%
t_5
# Out:
# 2     3
# 4     9
# 7     5
# 1     6
# 9    56
# 2    23
# 4    89
# 6    12
# 1    59
# 2    40
# dtype: int64

# %%
t_5[4]
# Out:
# 4     9
# 4    89
# dtype: int64

# %%
t_5[0:5]
# Out:
# 2     3
# 4     9
# 7     5
# 1     6
# 9    56
# dtype: int64

# %%
t_3
# Out:
# 2    3
# 4    9
# 7    5
# 1    6
# dtype: int64

# %%
t_4
# Out:
# 9    56
# 2    23
# 4    89
# 6    12
# 1    59
# 2    40
# dtype: int64

# %%
t_3*t_4
# Out:
# 1    354.0
# 2     69.0
# 2    120.0
# 4    801.0
# 6      NaN
# 7      NaN
# 9      NaN
# dtype: float64

# %%
t_3+t_4
# Out:
# 1    65.0
# 2    26.0
# 2    43.0
# 4    98.0
# 6     NaN
# 7     NaN
# 9     NaN
# dtype: float64

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'new_col', 'new_col_1'],
#       dtype='object')

# %%
# if we use drop function - by default it has axis = 0 
# so to delete the column we will give index=1
# it does not delete permanent because (inplace = false )
df.drop('survived',axis = 1)
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# 0         3    male  22.0      1      0   7.2500        S   Third    man
# 1         1  female  38.0      1      0  71.2833        C   First  woman
# 2         3  female  26.0      0      0   7.9250        S   Third  woman
# 3         1  female  35.0      1      0  53.1000        S   First  woman
# 4         3    male  35.0      0      0   8.0500        S   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886       2    male  27.0      0      0  13.0000        S  Second    man
# 887       1  female  19.0      0      0  30.0000        S   First  woman
# 888       3  female   NaN      1      2  23.4500        S   Third  woman
# 889       1    male  26.0      0      0  30.0000        C   First    man
# 890       3    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone  new_col  new_col_1
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
# to delete permanent inplace = true
df.drop('survived',axis = 1, inplace=True)

# %%
df
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# 0         3    male  22.0      1      0   7.2500        S   Third    man
# 1         1  female  38.0      1      0  71.2833        C   First  woman
# 2         3  female  26.0      0      0   7.9250        S   Third  woman
# 3         1  female  35.0      1      0  53.1000        S   First  woman
# 4         3    male  35.0      0      0   8.0500        S   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886       2    male  27.0      0      0  13.0000        S  Second    man
# 887       1  female  19.0      0      0  30.0000        S   First  woman
# 888       3  female   NaN      1      2  23.4500        S   Third  woman
# 889       1    male  26.0      0      0  30.0000        C   First    man
# 890       3    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone  new_col  new_col_1
# ...

# %%
df.drop(3)
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# 0         3    male  22.0      1      0   7.2500        S   Third    man
# 1         1  female  38.0      1      0  71.2833        C   First  woman
# 2         3  female  26.0      0      0   7.9250        S   Third  woman
# 4         3    male  35.0      0      0   8.0500        S   Third    man
# 5         3    male   NaN      0      0   8.4583        Q   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886       2    male  27.0      0      0  13.0000        S  Second    man
# 887       1  female  19.0      0      0  30.0000        S   First  woman
# 888       3  female   NaN      1      2  23.4500        S   Third  woman
# 889       1    male  26.0      0      0  30.0000        C   First    man
# 890       3    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone  new_col  new_col_1
# ...

# %%
# to set index - to set the column as index 
# here also inplace is false 
df.set_index("sex", inplace=True)

# %%
df
# Out:
#         pclass   age  sibsp  parch     fare embarked   class    who  \
# sex
# male         3  22.0      1      0   7.2500        S   Third    man
# female       1  38.0      1      0  71.2833        C   First  woman
# female       3  26.0      0      0   7.9250        S   Third  woman
# female       1  35.0      1      0  53.1000        S   First  woman
# male         3  35.0      0      0   8.0500        S   Third    man
# ...        ...   ...    ...    ...      ...      ...     ...    ...
# male         2  27.0      0      0  13.0000        S  Second    man
# female       1  19.0      0      0  30.0000        S   First  woman
# female       3   NaN      1      2  23.4500        S   Third  woman
# male         1  26.0      0      0  30.0000        C   First    man
# male         3  32.0      0      0   7.7500        Q   Third    man
#
#         adult_male deck  embark_town alive  alone  new_col  new_col_1
# sex
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         sex  pclass   age  sibsp  parch     fare embarked   class    who  \
# 0      male       3  22.0      1      0   7.2500        S   Third    man
# 1    female       1  38.0      1      0  71.2833        C   First  woman
# 2    female       3  26.0      0      0   7.9250        S   Third  woman
# 3    female       1  35.0      1      0  53.1000        S   First  woman
# 4      male       3  35.0      0      0   8.0500        S   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886    male       2  27.0      0      0  13.0000        S  Second    man
# 887  female       1  19.0      0      0  30.0000        S   First  woman
# 888  female       3   NaN      1      2  23.4500        S   Third  woman
# 889    male       1  26.0      0      0  30.0000        C   First    man
# 890    male       3  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone  new_col  new_col_1
# ...

# %%
d= {
    'key1' : [3,4,5,6],
    'key2' : [5,6,7,8],
    'key3' : [4,2,3,5]
}

# %%
# to make dictonary into dataframe 
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     2
# 2     5     7     3
# 3     6     8     5

# %%
# drop NaN value - removes those rows 
df.dropna()
# Out:
#         sex  pclass   age  sibsp  parch     fare embarked  class    who  \
# 1    female       1  38.0      1      0  71.2833        C  First  woman
# 3    female       1  35.0      1      0  53.1000        S  First  woman
# 6      male       1  54.0      0      0  51.8625        S  First    man
# 10   female       3   4.0      1      1  16.7000        S  Third  child
# 11   female       1  58.0      0      0  26.5500        S  First  woman
# ..      ...     ...   ...    ...    ...      ...      ...    ...    ...
# 871  female       1  47.0      1      1  52.5542        S  First  woman
# 872    male       1  33.0      0      0   5.0000        S  First    man
# 879  female       1  56.0      0      1  83.1583        C  First  woman
# 887  female       1  19.0      0      0  30.0000        S  First  woman
# 889    male       1  26.0      0      0  30.0000        C  First    man
#
#      adult_male deck  embark_town alive  alone  new_col  new_col_1
# ...

# %%
df
# Out:
#         sex  pclass   age  sibsp  parch     fare embarked   class    who  \
# 0      male       3  22.0      1      0   7.2500        S   Third    man
# 1    female       1  38.0      1      0  71.2833        C   First  woman
# 2    female       3  26.0      0      0   7.9250        S   Third  woman
# 3    female       1  35.0      1      0  53.1000        S   First  woman
# 4      male       3  35.0      0      0   8.0500        S   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886    male       2  27.0      0      0  13.0000        S  Second    man
# 887  female       1  19.0      0      0  30.0000        S   First  woman
# 888  female       3   NaN      1      2  23.4500        S   Third  woman
# 889    male       1  26.0      0      0  30.0000        C   First    man
# 890    male       3  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone  new_col  new_col_1
# ...

# %%
# to remove that column which has NaN values 
df.dropna(axis= 1)
# Out:
#         sex  pclass  sibsp  parch     fare   class    who  adult_male alive  \
# 0      male       3      1      0   7.2500   Third    man        True    no
# 1    female       1      1      0  71.2833   First  woman       False   yes
# 2    female       3      0      0   7.9250   Third  woman       False   yes
# 3    female       1      1      0  53.1000   First  woman       False   yes
# 4      male       3      0      0   8.0500   Third    man        True    no
# ..      ...     ...    ...    ...      ...     ...    ...         ...   ...
# 886    male       2      0      0  13.0000  Second    man        True    no
# 887  female       1      0      0  30.0000   First  woman       False   yes
# 888  female       3      1      2  23.4500   Third  woman       False    no
# 889    male       1      0      0  30.0000   First    man        True   yes
# 890    male       3      0      0   7.7500   Third    man        True    no
#
#      alone  new_col  new_col_1
# ...

# %%
df
# Out:
#         sex  pclass   age  sibsp  parch     fare embarked   class    who  \
# 0      male       3  22.0      1      0   7.2500        S   Third    man
# 1    female       1  38.0      1      0  71.2833        C   First  woman
# 2    female       3  26.0      0      0   7.9250        S   Third  woman
# 3    female       1  35.0      1      0  53.1000        S   First  woman
# 4      male       3  35.0      0      0   8.0500        S   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886    male       2  27.0      0      0  13.0000        S  Second    man
# 887  female       1  19.0      0      0  30.0000        S   First  woman
# 888  female       3   NaN      1      2  23.4500        S   Third  woman
# 889    male       1  26.0      0      0  30.0000        C   First    man
# 890    male       3  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone  new_col  new_col_1
# ...

# %%
df.fillna("bhumi")
# Out:
#         sex  pclass    age  sibsp  parch     fare embarked   class    who  \
# 0      male       3   22.0      1      0   7.2500        S   Third    man
# 1    female       1   38.0      1      0  71.2833        C   First  woman
# 2    female       3   26.0      0      0   7.9250        S   Third  woman
# 3    female       1   35.0      1      0  53.1000        S   First  woman
# 4      male       3   35.0      0      0   8.0500        S   Third    man
# ..      ...     ...    ...    ...    ...      ...      ...     ...    ...
# 886    male       2   27.0      0      0  13.0000        S  Second    man
# 887  female       1   19.0      0      0  30.0000        S   First  woman
# 888  female       3  bhumi      1      2  23.4500        S   Third  woman
# 889    male       1   26.0      0      0  30.0000        C   First    man
# 890    male       3   32.0      0      0   7.7500        Q   Third    man
#
#      adult_male   deck  embark_town alive  alone  new_col  new_col_1
# ...

# %%
g = df.groupby('sex')

# %%
g

# %%
g.sum()
# Out:
#         pclass       age  sibsp  parch        fare  \
# sex
# female     678   7286.00    218    204  13966.6628
# male      1379  13919.17    248    136  14727.2865
#
#                                                  embarked  \
# sex
# female  CSSSCSSSSSCQSSQCQSCSSCQQSCSSSSSSSQSSSSSSQCSCSS...
# male    SSQSSSSQSSSSCSSCSCSCSCSQCSSCSCSCSSCCSSSSCSSSSS...
#
#                                                     class  \
# sex
# female  FirstThirdFirstThirdSecondThirdFirstThirdSecon...
# male    ThirdThirdThirdFirstThirdThirdThirdThirdSecond...
#
#                                                       who  adult_male  \
# sex
# female  womanwomanwomanwomanchildchildwomanchildwomanw...           0
# male    manmanmanmanchildmanmanchildmanmanmanmanmanman...         537
#
#                                                      deck  \
# sex
# female  CCGCBDBFCEFDCECBBGDDCGBCCDBCBECECBCECDBECFEDBD...
# male    EDACBCCFEADDCBDCBFBAFAFACCDCEBCADCCCCCFCECBECE...
#
# ...

# %%
h = df.groupby('pclass')
h

# %%
h.sum()
# Out:
#                                                       sex      age  sibsp  \
# pclass
# 1       femalefemalemalefemalemalemalemalefemalemalema...  7111.42     90
# 2       femalefemalemalemalemalemalefemalefemalefemale...  5168.83     74
# 3       malefemalemalemalemalefemalefemalemalemalefema...  8924.92    302
#
#         parch        fare                                           embarked  \
# pclass
# 1          77  18177.4125  CSSSSSCCCSCCSSCSSSCCSSCSSSCSCSSSCCSSCCCCCSSQSS...
# 2          70   3801.8417  CSSSSSSCSSSSSSSSSSSSCSSSCSSSSSSSCSSSSSSSSSSSSS...
# 3         193   6714.6951  SSSQSSSSSSQSCQSSCQSQCSSCSCQSQQCSSSCSCSCSSSSCSS...
#
#                                                     class  \
# pclass
# 1       FirstFirstFirstFirstFirstFirstFirstFirstFirstF...
# 2       SecondSecondSecondSecondSecondSecondSecondSeco...
# 3       ThirdThirdThirdThirdThirdThirdThirdThirdThirdT...
#
#                                                       who  adult_male  \
# pclass
# ...

# %%
# to transpose 
df.T
# Out:
#                      0          1            2            3            4    \
# sex                 male     female       female       female         male
# pclass                 3          1            3            1            3
# age                 22.0       38.0         26.0         35.0         35.0
# sibsp                  1          1            0            1            0
# parch                  0          0            0            0            0
# fare                7.25    71.2833        7.925         53.1         8.05
# embarked               S          C            S            S            S
# class              Third      First        Third        First        Third
# who                  man      woman        woman        woman          man
# adult_male          True      False        False        False         True
# deck                 NaN          C          NaN            C          NaN
# ...

# %%
data1= pd.DataFrame( {
    'key1' : [3,4,5,6],
    'key2' : [5,6,7,8],
    'key3' : [4,2,3,5]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     2
# 2     5     7     3
# 3     6     8     5

# %%
data2= pd.DataFrame( {
    'key1' : [2,4,5,6],
    'key2' : [9,8,7,8],
    'key3' : [1,2,7,5]
})

# %%
data2
# Out:
#    key1  key2  key3
# 0     2     9     1
# 1     4     8     2
# 2     5     7     7
# 3     6     8     5

# %%
i = pd.merge(data1, data2 , how ='left')

# %%
i
# Out:
#    key1  key2  key3
# 0    32    95    14
# 1    49    86    12
# 2    57    47    13
# 3    62    18    25

# %%
pd.merge(data1, data2 , how ='cross' )
# Out:
#     key1_x  key2_x  key3_x  key1_y  key2_y  key3_y
# 0       32      95      14       2       9       1
# 1       32      95      14       4       8       2
# 2       32      95      14       5       7       7
# 3       32      95      14       6       8       5
# 4       49      86      12       2       9       1
# 5       49      86      12       4       8       2
# 6       49      86      12       5       7       7
# 7       49      86      12       6       8       5
# 8       57      47      13       2       9       1
# 9       57      47      13       4       8       2
# 10      57      47      13       5       7       7
# 11      57      47      13       6       8       5
# 12      62      18      25       2       9       1
# 13      62      18      25       4       8       2
# 14      62      18      25       5       7       7
# 15      62      18      25       6       8       5
